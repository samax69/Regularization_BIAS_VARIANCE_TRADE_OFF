# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes

# %%
X , y = load_diabetes(return_X_y = True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
#Here we'll apply Lasso Regression using inbuilt class

# %%
from sklearn.linear_model import Lasso

# %%
las = Lasso(alpha = 0.1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2)

# %%
las.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred = las.predict(X_test)

# %%
las.coef_
# Out:
# array([   0.        , -121.94135145,  527.18367076,  274.13058352,
#         -18.51881711,   -0.        , -233.54160575,    0.        ,
#         423.16677575,    0.        ])

# %%
las.intercept_
# Out:
# 150.6744263362286

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.5219783380715901

# %% [markdown]
# # Here Now we will go with ElasticNet a|W| + b(W)^2

# %%
from sklearn.linear_model import ElasticNet

# %%
es = ElasticNet(alpha = 0.0001, l1_ratio = 0.9)

# %%
es.fit(X_train , y_train)
# Out:
# ElasticNet(alpha=0.0001, l1_ratio=0.9)

# %%
y_pred2 = es.predict(X_test)

# %%
r2_score(y_test , y_pred2)
# Out:
# 0.5296422483649069
